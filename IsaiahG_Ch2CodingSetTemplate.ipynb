# %% [markdown]
# # Chapter 2 Coding Set
#
# **Remember to save a copy of this template BEFORE YOU START WORKING :)**
#
# Work completed by Isaiah Garrison.
#
# If you struggle with a problem for an extended period of time, remember you can go comment on two other submissions now (seeing other student work helps), or you can post in our discussion forum for questions, which can also earn you extra credit.

# %% [markdown]
# ## Imports
#
# **If your program requires additional modules, external resources, or files, use this cell to set them up**

# %%
# configure your environment

# you can uncomment this code to make use of files stored in your Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# you can uncomment the following line of code to use the pandas library
# import pandas as pd

# %% [markdown]
# ## Algorithm Workbench

# %% [markdown]
# ### Problem 2
#
# #### Question Text
#
# Write Python code that prompts the user to enter his or her favorite color and assigns the user’s input to a variable named color.
#
# #### High-Level Overview
#
# Starting this proble, I had to just stick with the basics and what I know so far. I kept it simple and knew how to solve this problem so I took it slow and wrote down my answer. After every step, I checked to see if the code works and I had no mistakes. This problem was easy for me.
#
# [Please double click this cell and update the problem number above, choosing one of the Algorithm Workbench problems from Chapter 2 of your textbook. Then, update the question text. Finally, once you've completed the problem, please replace the high-level overview placeholder text with your own words describing your solution.]

# %%
# add your code to this cell
# remember to include comments like this one for every line of code
# remember to "Run cell" once you're done, excecuting your code so the output is displayed below

# Ask user for their favorite color
color = input("What is your favorite color?:  ")

# Print the color
print(f"Your favorite color is:  " + color)
# Out:
# What is your favorite color?:   Blue
# Your favorite color is:  Blue

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem 3
#
# #### Question Text
#
# One acre of land is equivalent to 43,560 square feet. Write a program that asks the user to enter the total square feet in a tract of land and calculates the number of acres in the tract.
#
# #### High-Level Overview
#
# Going into this question, I knew would be more difficult so I took it more slow. I broke it down into steps as seen from the comments. I had some knowledge going into this on how to perform each action. I did have an error when printing the text but it was a simple mistake that happened from trying to go too fast near the end. I did need to remember how to print a number variable but I remembered how. Overall feeling good.
#
# [Please double click this cell and update the problem number above, choosing one of the problems besides number 13 from the Chapter 2 Programming Exercises in your textbook. Then, update the question text. Finally, once you've completed the problem, please replace the high-level overview placeholder text with your own words describing your solution.]

# %%
# add your code to this cell
# remember to include comments like this one for every line of code
# remember to "Run cell" once you're done, excecuting your code so the output is displayed below

# Ask user to enter total square feet in a tract of land
user_squarefeet = float(input("Please enter the total square feet in a tract of land:  "))

# Convert square feet to ancers in the tract
result = user_squarefeet / 43560

# Print the number of acres to User
print(f"This is how many acres that much square feet equals:  ", result,)
# Out:
# Please enter the total square feet in a tract of land:   43
# This is how many acres that much square feet equals:   0.0009871441689623508

# %% [markdown]
# ### Problem 13
#
# #### Question Text
#
# A vineyard owner is planting several new rows of grapevines, and needs to know how many grapevines to plant in each row. She has determined that after measuring the length of a future row, she can use the following formula to calculate the number of vines that will fit in the row, along with the trellis end-post assemblies that will need to be constructed at each end of the row:
#
# The terms in the formula are:  V is the number of grapevines that will fit in the row.                            R is the length of the row, in feet.                            E is the amount of space, in feet, used by an end-post assembly.                            S is the space between vines, in feet.Write a program that makes the calculation for the vineyard owner. The program should ask the user to input the following:    The length of the row, in feet  The amount of space used by an end-post assembly, in feet  The amount of space between the vines, in feetOnce the input data has been entered, the program should calculate and display the number of grapevines that will fit in the row.
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
# add your code to this cell
# remember to include comments like this one for every line of code
# remember to "Run cell" once you're done, excecuting your code so the output is displayed below

# %% [markdown]
# ## Helpful Checks
#
# 1.   Did you comment every line of code with meaningful information that will help others reading your code?
# 2.   Did you use appropriate names for your variables, functions, and/or classes?
# 3.   Did you include a high-level explanation for each solution?
# 4.   Did you run each cell that includes a final solution so the output is saved and easily viewed by others?
# 5.   Are you sharing an editable link (i.e., Share > Anyone with the link > Editor) if using Colaboratory, or did you make more than ten commits if using GitHub?
# 6.   Did you remember to comment on the submissions of two other students?
